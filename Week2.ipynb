# %% [markdown]
# <a href="https://colab.research.google.com/github/nargyanti/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practicum

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) # convert channel BGR > RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

# show plot with larger canvas
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384, 0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200, 200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100, 100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400, 400), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0, 0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Task

# %%
img6 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img7 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# show plot with larger canvas
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

print("image resolution: height x width = ", img6.shape[0], " x ", img6.shape[1])
print("image resolution: height x width = ", img7.shape[0], " x ", img7.shape[1])
ax.imshow(img7)
# Out:
# image resolution: height x width =  627  x  670
# image resolution: height x width =  627  x  670

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
kitten_red_green = cv.cvtColor(cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg'), cv.COLOR_BGR2RGB)
kitten_red_green[:, :, 0] = 0
plt.imshow(kitten_red_green)

# %%
kitten_green_blue = cv.cvtColor(cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg'), cv.COLOR_BGR2RGB)
kitten_green_blue[:, :, 2] = 0
plt.imshow(kitten_green_blue)
# cv.waitKey(0)

# %%
kitten = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
crop_img = kitten[10:100, 10:100]
plt.imshow(crop_img)

# %%
kitten = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
kitten_height = kitten.shape[0]
kitten_width = kitten.shape[1]
print("image resolution: height x width = ", kitten_height, " x ", kitten_width)
# Out:
# image resolution: height x width =  627  x  670

# %%
crop_img_green = kitten[5:30, 0:670]
crop_img_green[:, :, 0] = 0
crop_img_green[:, :, 2] = 0
plt.imshow(crop_img_green)

# %%
import random
kitten = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
kitten_box = kitten
for i in range(5):
  cv.rectangle(kitten_box, pt1=(random.randint(0, kitten_box.shape[0]), random.randint(0, kitten_box.shape[1])), 
               pt2=(random.randint(0, kitten_box.shape[0]),random.randint(0, kitten_box.shape[1])), 
               color=(random.randint(0, 255),random.randint(0, 255),random.randint(0, 255)), thickness=10)
plt.imshow(kitten_box)

# %%
kitten = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
kitten_upside_down = cv.flip(kitten, 0)
plt.imshow(kitten_upside_down)

# %%
nabilah = cv.imread('/content/drive/MyDrive/PCVK/Nabilah.jpg')
nabilah_rgb = cv.cvtColor(nabilah, cv.COLOR_BGR2RGB)
print("image resolution: height x width = ", nabilah_rgb.shape[0], " x ", nabilah_rgb.shape[1])
plt.imshow(nabilah_rgb)
# Out:
# image resolution: height x width =  480  x  640

# %%
cv.rectangle(nabilah_rgb, pt1=(180, 150), pt2=(450,400), color=(0,0,255), thickness=10)
cv.circle(nabilah_rgb, center=(320, 280), radius=100, color=(255,0,0), thickness=10)
plt.imshow(nabilah_rgb)

# %%
lena = cv.imread('/content/drive/MyDrive/PCVK/lena.jpg')
lena[:, :, 1] = 0
lena[:, :, 2] = 0
cv.rectangle(lena, pt1=(10, 500), pt2=(150,400), color=(0,0,255), thickness=-1)
plt.imshow(lena)

# %%
font = cv.FONT_HERSHEY_TRIPLEX
cv.putText(lena, text='LENA', org=(10,100), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(lena)

# %%
io.imshow(lena)
